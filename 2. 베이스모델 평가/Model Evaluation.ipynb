# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: NVIDIA A100-SXM4-80GB

# %%
# !pip install --upgrade pip
# !pip install "lm-eval>=0.4" transformers accelerate datasets sentencepiece
# !pip install huggingface_hub

# %%
from huggingface_hub import login
login()   # 여기서 hf_... 토큰 입력

# %%
import os

# TF32 허용 (Ampere 이상 GPU에서 속도 ↑)
os.environ["TORCH_ALLOW_TF32"] = "1"

# CUDA 메모리 파편화 방지
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:128,expandable_segments:True"

# %%
# !python -m lm_eval --help | head -n 20
# Out:
# usage: __main__.py [-h] [--model MODEL] [--tasks task1,task2]
#                    [--model_args MODEL_ARGS] [--num_fewshot N]
#                    [--batch_size auto|auto:N|N] [--max_batch_size N]
#                    [--device DEVICE] [--output_path DIR|DIR/file.json]
#                    [--limit N|0<N<1] [--samples /path/to/json]
#                    [--use_cache DIR] [--cache_requests {true,refresh,delete}]
#                    [--check_integrity] [--write_out] [--log_samples]
#                    [--system_instruction SYSTEM_INSTRUCTION]
#                    [--apply_chat_template [APPLY_CHAT_TEMPLATE]]
#                    [--fewshot_as_multiturn] [--show_config]
#                    [--include_path DIR] [--gen_kwargs GEN_KWARGS]
#                    [--verbosity CRITICAL|ERROR|WARNING|INFO|DEBUG]
#                    [--wandb_args WANDB_ARGS]
#                    [--wandb_config_args WANDB_CONFIG_ARGS]
#                    [--hf_hub_log_args HF_HUB_LOG_ARGS] [--predict_only]
# ...

# %%
# !python -m lm_eval --model hf --device cuda \
  --model_args pretrained=LGAI-EXAONE/EXAONE-3.5-2.4B-Instruct,dtype=float16,device_map=auto,trust_remote_code=True \
  --tasks kmmlu --num_fewshot 5 --apply_chat_template \
  --batch_size auto --max_batch_size 8 \
  --output_path results/exaone_3p5_2p4b_instruct_test
# Out:
# 2025-09-23 06:41:01.950866: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 06:41:01.968335: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758609661.989693   13067 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758609661.996504   13067 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from google.colab import files
files.download("/content/results/exaone_3p5_2p4b_instruct_test/LGAI-EXAONE__EXAONE-3.5-2.4B-Instruct/results_2025-09-23T07-10-04.414763.json")

# %%
# !python -m lm_eval --model hf --device cuda \
  --model_args pretrained=kakaocorp/kanana-nano-2.1b-instruct,dtype=float16,device_map=auto,trust_remote_code=True \
  --tasks kmmlu --num_fewshot 5 --apply_chat_template \
  --batch_size auto --max_batch_size 8 \
  --output_path results/kanana_2p1b_instruct_test
# Out:
# 2025-09-23 07:22:30.468964: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 07:22:30.487300: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758612150.508832   24140 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758612150.515379   24140 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from google.colab import files
files.download("/content/results/kanana_2p1b_instruct_test/kakaocorp__kanana-nano-2.1b-instruct/results_2025-09-23T07-46-55.517480.json")

# %%
# !python -m lm_eval --model hf --device cuda \
  --model_args pretrained=Qwen/Qwen2.5-1.5B-Instruct,dtype=float16,device_map=auto,trust_remote_code=True \
  --tasks kmmlu --num_fewshot 5 --apply_chat_template \
  --batch_size auto --max_batch_size 8\
  --output_path results/qwen25_1p5b_instruct_test
# Out:
# 2025-09-23 07:49:11.577802: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 07:49:11.595941: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758613751.617763   31428 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758613751.624425   31428 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from google.colab import files
files.download("/content/results/qwen25_1p5b_instruct_test/Qwen__Qwen2.5-1.5B-Instruct/results_2025-09-23T08-12-41.280185.json")

# %%
# !python -m lm_eval --model hf --device cuda \
  --model_args pretrained=naver-hyperclovax/HyperCLOVAX-SEED-Text-Instruct-1.5B,dtype=float16,device_map=auto,trust_remote_code=True \
  --tasks kmmlu --num_fewshot 5 --apply_chat_template \
  --batch_size auto --max_batch_size 8 \
  --output_path results/hyperclovax_1p5b_instruct_test
# Out:
# 2025-09-23 08:14:19.208366: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 08:14:19.226508: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758615259.248038   38370 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758615259.254548   38370 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from google.colab import files
files.download("/content/results/hyperclovax_1p5b_instruct_test/naver-hyperclovax__HyperCLOVAX-SEED-Text-Instruct-1.5B/results_2025-09-23T08-35-52.777836.json")
